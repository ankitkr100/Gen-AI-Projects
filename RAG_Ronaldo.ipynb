# %%
from transformers import pipeline

# %%
def retrieve_documents(query, vector_db):
    if "Cristiano Ronaldo" in query:
      return [
          "Cristiano Ronaldo is a footballer...",
          "He is very good at penalty."
          ]
      return [" No relevant documents found."]
def generate_response(llm_model, query, context):
  prompt = f" Based on the following context, answer the query. \n\nContext: {context}\n \nQuery: {query}"
  print("Sending prompt to LLM...")
  print(f"Prompt sent: {prompt}")
  return "Response generated based on provided context"

# %%
query = "Who is Cristiano Ronaldo?"

# %%
retrieved_docs = retrieve_documents(query1, vector_db = "my_vector_db")

# %%
context_string = " ".join(retrieved_docs)

# %%
final_response = generate_response(llm_model="gpt-4", query=query1, context=context_string)
# Out:
# Sending prompt to LLM...
# Prompt sent:  Based on the following context, answer the query.
#
# Context: Cristiano Ronaldo is a footballer... He is very good at penalty.
#
# Query: Who is Cristiano Ronaldo?

# %%
print("\nFinal Response:", final_response)
# Out:
# Final Response: Response generated based on provided context
